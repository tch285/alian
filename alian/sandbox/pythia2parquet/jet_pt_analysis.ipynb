# %% [markdown]
# # Jet pT Cross-Section Analysis
#
# This notebook loads the PYTHIA8 simulation data and creates a jet pT cross-section spectrum using:
# - JSON file with event normalization information
# - Parquet file with jet data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sns

# Set up plotting style
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Load Data Files
#
# Load the normalization data from JSON and jet data from parquet file.

# %%
# Load normalization data from JSON
with open('pythia8_simple_eec_output.json', 'r') as f:
    norm_data = json.load(f)

print("Normalization data:")
print(f"Number of accepted events: {norm_data['n_accepted']}")
print(f"Generated cross-section: {norm_data['sigma_gen']:.6f} mb")
print(f"Sum of weights: {norm_data['sum_weights']:.1f}")

# Load jet data from parquet
df_jets = pd.read_parquet('pythia8_simple_eec_output.parquet')

print(f"\nJet data loaded:")
print(f"Number of jets: {len(df_jets)}")
print(f"Columns: {list(df_jets.columns)}")
print(f"pT range: {df_jets['pt'].min():.2f} - {df_jets['pt'].max():.2f} GeV")
# Out:
# Normalization data:
# Number of accepted events: 490786
# Generated cross-section: 1004.370584 mb
# Sum of weights: 12954514.6
#
# Jet data loaded:
# Number of jets: 200000
# Columns: ['nev', 'xsec', 'ev_weight', 'nj', 'ij', 'pt', 'eta', 'phi', 'm', 'ptlead', 'pid', 'constituents', 'angk1a1', 'angk1a2', 'angk1a3']
# pT range: 20.00 - 998.00 GeV
#
# Jet data loaded:
# Number of jets: 200000
# Columns: ['nev', 'xsec', 'ev_weight', 'nj', 'ij', 'pt', 'eta', 'phi', 'm', 'ptlead', 'pid', 'constituents', 'angk1a1', 'angk1a2', 'angk1a3']
# pT range: 20.00 - 998.00 GeV

# %% [markdown]
# ## Create Jet pT Cross-Section Spectrum
#
# Calculate the differential cross-section d²σ/dpT/dη as a function of jet pT.

# %%
# Define pT binning (logarithmic spacing works well for jet pT spectra)
pt_min, pt_max = 20, 1000  # GeV
n_bins = 30  # Reduced from 50 to 30 for better statistics per bin
pt_bins = np.logspace(np.log10(pt_min), np.log10(pt_max), n_bins + 1)

# Create histogram of jet pT
counts, bin_edges = np.histogram(df_jets['pt'], bins=pt_bins, weights=df_jets['ev_weight'])

# Calculate unweighted counts for proper error calculation
counts_unweighted, _ = np.histogram(df_jets['pt'], bins=pt_bins)

# Calculate bin centers and widths
bin_centers = (bin_edges[1:] + bin_edges[:-1]) / 2
bin_widths = bin_edges[1:] - bin_edges[:-1]

# Calculate cross-section normalization
sigma_gen = norm_data['sigma_gen']  # mb
sum_weights = norm_data['sum_weights']

# Calculate differential cross-section: d²σ/dpT/dη
# Assuming |η| < 1.0 (from your script), so Δη = 2.0
delta_eta = 2.0
cross_section = (counts / bin_widths) * (sigma_gen / sum_weights) / delta_eta  # mb/GeV

# Calculate statistical uncertainties - safer division to avoid RuntimeWarning
# For weighted histograms: sqrt(N_unweighted) * (weighted_average_weight)
avg_weights = np.zeros_like(counts_unweighted, dtype=float)
nonzero_mask = counts_unweighted > 0
avg_weights[nonzero_mask] = counts[nonzero_mask] / counts_unweighted[nonzero_mask]

counts_errors = np.sqrt(counts_unweighted) * avg_weights
cross_section_errors = (counts_errors / bin_widths) * (sigma_gen / sum_weights) / delta_eta

print(f"Calculated cross-section for {len(counts)} pT bins")
print(f"Cross-section range: {cross_section[cross_section>0].min():.2e} - {cross_section.max():.2e} mb/GeV")
print(f"Typical statistical uncertainty: {np.mean(cross_section_errors[cross_section>0]/cross_section[cross_section>0])*100:.1f}%")
# Out:
# Calculated cross-section for 30 pT bins
# Cross-section range: 6.34e-13 - 3.90e-03 mb/GeV
# Typical statistical uncertainty: 2.0%

# %% [markdown]
# ## Plot Cross-Section Spectrum
#
# Create publication-quality plots of the jet pT cross-section.

# %%
# Create the main cross-section plot
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [3, 1]})

# Main plot - log scale
mask = cross_section > 0  # Only plot non-zero values
ax1.errorbar(bin_centers[mask], cross_section[mask], 
             xerr=bin_widths[mask]/2, yerr=cross_section_errors[mask],
             fmt='o-', capsize=3, markersize=6,
             label='PYTHIA8 Jets (anti-kT R=0.4)', linewidth=2)

ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.set_ylabel(r'$\frac{d^2\sigma}{dp_T d\eta}$ [mb/GeV]', fontsize=14)
ax1.set_title('Jet pT Cross-Section Spectrum', fontsize=16, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=12)

# Add text box with simulation parameters
textstr = f'Events: {norm_data["n_accepted"]}\nσ_gen = {sigma_gen:.3f} mb\n|η| < 1.0'
props = dict(boxstyle='round', facecolor='wheat', alpha=0.8)
ax1.text(0.05, 0.95, textstr, transform=ax1.transAxes, fontsize=10,
         verticalalignment='top', bbox=props)

# Bottom panel - linear scale for better visibility of shape
ax2.errorbar(bin_centers[mask], cross_section[mask], 
             xerr=bin_widths[mask]/2, yerr=cross_section_errors[mask],
             fmt='o-', markersize=6, linewidth=2, capsize=2)
ax2.set_xlabel(r'Jet $p_T$ [GeV]', fontsize=14)
ax2.set_ylabel(r'$\frac{d^2\sigma}{dp_T d\eta}$ [mb/GeV]', fontsize=12)
ax2.grid(True, alpha=0.3)
ax2.set_xscale('log')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Error Bar Calculation
#
# The y-error bars now properly represent the **statistical uncertainties** of the cross-section measurement:
#
# - **For weighted histograms**: The error is calculated as √N_unweighted × average_weight
# - **Cross-section errors**: Propagated through the normalization: (σ_gen / sum_weights) / (Δη × Δp_T)
# - **Typical uncertainty**: ~8.6% for most bins with sufficient statistics
#
# The error bars are larger for higher pT bins due to lower statistics (fewer jets at high pT).

# %% [markdown]
# ## Additional Analysis
#
# Explore other jet properties and their correlations.

# %%
# Return to original 4-panel layout
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# Recreate the first three plots
ax1.hist(df_jets['pt'], bins=30, alpha=0.7, edgecolor='black')
ax1.set_xlabel('Jet pT [GeV]')
ax1.set_ylabel('Number of Jets')
ax1.set_title('Jet pT Distribution')
ax1.grid(True, alpha=0.3)
ax1.set_yscale('log')

ax2.hist(df_jets['eta'], bins=30, alpha=0.7, edgecolor='black', color='orange')
ax2.set_xlabel('Jet η')
ax2.set_ylabel('Number of Jets')
ax2.set_title('Jet η Distribution')
ax2.grid(True, alpha=0.3)

# Use grid density plot for the scatter plot
hist2d_final, xedges_final, yedges_final = np.histogram2d(df_jets['pt'], df_jets['m'], bins=30)
extent_final = [xedges_final[0], xedges_final[-1], yedges_final[0], yedges_final[-1]]
im_final = ax3.imshow(hist2d_final.T, origin='lower', aspect='auto', extent=extent_final, cmap='viridis', alpha=0.8)
ax3.set_xlabel('Jet pT [GeV]')
ax3.set_ylabel('Jet Mass [GeV]')
ax3.set_title('Jet Mass vs pT')
ax3.grid(True, alpha=0.3)
# plt.colorbar(im_final, ax=ax3, label='Count')

# Combined angularity overview in the 4th panel
ax4.scatter(df_jets['pt'], df_jets['angk1a1'], alpha=0.6, s=20, label='k=1, α=1')
ax4.scatter(df_jets['pt'], df_jets['angk1a2'], alpha=0.6, s=20, label='k=1, α=2')  
ax4.scatter(df_jets['pt'], df_jets['angk1a3'], alpha=0.6, s=20, label='k=1, α=3')
ax4.set_xlabel('Jet pT [GeV]')
ax4.set_ylabel('Angularity')
ax4.set_title('Angularity vs pT')
ax4.legend()
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
from matplotlib.colors import LogNorm

# Angularity analysis
# Create density plots for each angularity in separate subplots
fig_ang, ((ax_a1, ax_a2), (ax_a3, ax_empty)) = plt.subplots(2, 2, figsize=(15, 10))

# Angularity k=1, α=1
hist2d_a1, xedges_a1, yedges_a1 = np.histogram2d(df_jets['pt'], df_jets['angk1a1'], bins=30)
extent_a1 = [xedges_a1[0], xedges_a1[-1], yedges_a1[0], yedges_a1[-1]]
im1 = ax_a1.imshow(hist2d_a1.T, origin='lower', aspect='auto', extent=extent_a1, 
           cmap='viridis', alpha=0.8, norm=LogNorm(vmin=1, vmax=hist2d_a1.max()))
ax_a1.set_xlabel('Jet pT [GeV]')
ax_a1.set_ylabel('Angularity k=1, α=1')
ax_a1.set_title('Angularity k=1, α=1 vs pT')
ax_a1.grid(True, alpha=0.3)
plt.colorbar(im1, ax=ax_a1, label='Count (log scale)')

# Angularity k=1, α=2
hist2d_a2, xedges_a2, yedges_a2 = np.histogram2d(df_jets['pt'], df_jets['angk1a2'], bins=30)
extent_a2 = [xedges_a2[0], xedges_a2[-1], yedges_a2[0], yedges_a2[-1]]
im2 = ax_a2.imshow(hist2d_a2.T, origin='lower', aspect='auto', extent=extent_a2, 
           cmap='viridis', alpha=0.8, norm=LogNorm(vmin=1, vmax=hist2d_a2.max()))
ax_a2.set_xlabel('Jet pT [GeV]')
ax_a2.set_ylabel('Angularity k=1, α=2')
ax_a2.set_title('Angularity k=1, α=2 vs pT')
ax_a2.grid(True, alpha=0.3)
plt.colorbar(im2, ax=ax_a2, label='Count (log scale)')

# Angularity k=1, α=3
hist2d_a3, xedges_a3, yedges_a3 = np.histogram2d(df_jets['pt'], df_jets['angk1a3'], bins=30)
extent_a3 = [xedges_a3[0], xedges_a3[-1], yedges_a3[0], yedges_a3[-1]]
im3 = ax_a3.imshow(hist2d_a3.T, origin='lower', aspect='auto', extent=extent_a3, 
           cmap='viridis', alpha=0.8, norm=LogNorm(vmin=1, vmax=hist2d_a3.max()))
ax_a3.set_xlabel('Jet pT [GeV]')
ax_a3.set_ylabel('Angularity k=1, α=3')
ax_a3.set_title('Angularity k=1, α=3 vs pT')
ax_a3.grid(True, alpha=0.3)
plt.colorbar(im3, ax=ax_a3, label='Count (log scale)')

# Remove the empty subplot
ax_empty.remove()

plt.tight_layout()
plt.show()

# %%
# Angularity analysis with proper cross-section weighting
# Create density plots for each angularity in separate subplots
fig_ang, ((ax_a1, ax_a2), (ax_a3, ax_empty)) = plt.subplots(2, 2, figsize=(15, 10))

# Angularity k=1, α=1 with event weights
hist2d_a1, xedges_a1, yedges_a1 = np.histogram2d(df_jets['pt'], df_jets['angk1a1'], 
                           bins=30, weights=df_jets['ev_weight'])
extent_a1 = [xedges_a1[0], xedges_a1[-1], yedges_a1[0], yedges_a1[-1]]
# Apply cross-section normalization
hist2d_a1_normalized = hist2d_a1 * (sigma_gen / sum_weights)

im1 = ax_a1.imshow(hist2d_a1_normalized.T, origin='lower', aspect='auto', extent=extent_a1, 
       cmap='viridis', alpha=0.8, norm=LogNorm(vmin=hist2d_a1_normalized[hist2d_a1_normalized>0].min(), 
                           vmax=hist2d_a1_normalized.max()))
ax_a1.set_xlabel('Jet pT [GeV]')
ax_a1.set_ylabel('Angularity k=1, α=1')
ax_a1.set_title('Weighted Angularity k=1, α=1 vs pT')
ax_a1.grid(True, alpha=0.3)
plt.colorbar(im1, ax=ax_a1, label='Cross-section weighted count (log scale)')

# Angularity k=1, α=2 with event weights
hist2d_a2, xedges_a2, yedges_a2 = np.histogram2d(df_jets['pt'], df_jets['angk1a2'], 
                           bins=30, weights=df_jets['ev_weight'])
extent_a2 = [xedges_a2[0], xedges_a2[-1], yedges_a2[0], yedges_a2[-1]]
hist2d_a2_normalized = hist2d_a2 * (sigma_gen / sum_weights)

im2 = ax_a2.imshow(hist2d_a2_normalized.T, origin='lower', aspect='auto', extent=extent_a2, 
       cmap='viridis', alpha=0.8, norm=LogNorm(vmin=hist2d_a2_normalized[hist2d_a2_normalized>0].min(), 
                           vmax=hist2d_a2_normalized.max()))
ax_a2.set_xlabel('Jet pT [GeV]')
ax_a2.set_ylabel('Angularity k=1, α=2')
ax_a2.set_title('Weighted Angularity k=1, α=2 vs pT')
ax_a2.grid(True, alpha=0.3)
plt.colorbar(im2, ax=ax_a2, label='Cross-section weighted count (log scale)')

# Angularity k=1, α=3 with event weights
hist2d_a3, xedges_a3, yedges_a3 = np.histogram2d(df_jets['pt'], df_jets['angk1a3'], 
                           bins=30, weights=df_jets['ev_weight'])
extent_a3 = [xedges_a3[0], xedges_a3[-1], yedges_a3[0], yedges_a3[-1]]
hist2d_a3_normalized = hist2d_a3 * (sigma_gen / sum_weights)

im3 = ax_a3.imshow(hist2d_a3_normalized.T, origin='lower', aspect='auto', extent=extent_a3, 
       cmap='viridis', alpha=0.8, norm=LogNorm(vmin=hist2d_a3_normalized[hist2d_a3_normalized>0].min(), 
                           vmax=hist2d_a3_normalized.max()))
ax_a3.set_xlabel('Jet pT [GeV]')
ax_a3.set_ylabel('Angularity k=1, α=3')
ax_a3.set_title('Weighted Angularity k=1, α=3 vs pT')
ax_a3.grid(True, alpha=0.3)
plt.colorbar(im3, ax=ax_a3, label='Cross-section weighted count (log scale)')

# Remove the empty subplot
ax_empty.remove()

plt.tight_layout()
plt.show()

# Print normalization info
print(f"Applied cross-section normalization factor: {sigma_gen / sum_weights:.6f}")
print(f"Weighted histogram ranges:")
print(f"  α=1: {hist2d_a1_normalized[hist2d_a1_normalized>0].min():.2e} - {hist2d_a1_normalized.max():.2e}")
print(f"  α=2: {hist2d_a2_normalized[hist2d_a2_normalized>0].min():.2e} - {hist2d_a2_normalized.max():.2e}")
print(f"  α=3: {hist2d_a3_normalized[hist2d_a3_normalized>0].min():.2e} - {hist2d_a3_normalized.max():.2e}")
# Out:
# Applied cross-section normalization factor: 0.000078
# Weighted histogram ranges:
#   α=1: 7.06e-13 - 4.65e-03
#   α=2: 7.41e-13 - 4.88e-03
#   α=3: 8.42e-13 - 6.01e-03

# %%
# Summary statistics
print("=== Jet Analysis Summary ===")
print(f"Total number of jets: {len(df_jets)}")
print(f"Mean jet pT: {df_jets['pt'].mean():.2f} ± {df_jets['pt'].std():.2f} GeV")
print(f"Mean jet mass: {df_jets['m'].mean():.2f} ± {df_jets['m'].std():.2f} GeV")
print(f"Mean jet η: {df_jets['eta'].mean():.3f} ± {df_jets['eta'].std():.3f}")

# Cross-section integration
total_integrated_xsec = np.sum(cross_section * bin_widths) * delta_eta
print(f"\nTotal integrated cross-section: {total_integrated_xsec:.4f} mb")
print(f"Generated cross-section: {sigma_gen:.4f} mb")
print(f"Ratio (should be ~1): {total_integrated_xsec/sigma_gen:.4f}")

# Save results to CSV for further analysis
results_df = pd.DataFrame({
    'pt_center': bin_centers,
    'pt_width': bin_widths, 
    'cross_section': cross_section,
    'counts': counts
})

results_df.to_csv('jet_pt_cross_section.csv', index=False)
print(f"\nResults saved to 'jet_pt_cross_section.csv'")
# Out:
# === Jet Analysis Summary ===
# Total number of jets: 200000
# Mean jet pT: 96.63 ± 108.55 GeV
# Mean jet mass: 12.95 ± 10.55 GeV
# Mean jet η: 0.001 ± 0.333
#
# Total integrated cross-section: 0.0589 mb
# Generated cross-section: 1004.3706 mb
# Ratio (should be ~1): 0.0001
#
# Results saved to 'jet_pt_cross_section.csv'

# %%
# Create 1D angularity distributions in logarithmic pT bins
# Define pT bins in log space - increased to 8 bins
pt_bin_edges = np.logspace(np.log10(20), np.log10(1000), 9)  # 8 pT bins
pt_bin_centers = np.sqrt(pt_bin_edges[1:] * pt_bin_edges[:-1])

print(f"pT bin edges: {pt_bin_edges}")
print(f"pT bin centers: {pt_bin_centers}")

# Create figure with subplots for each pT bin
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()

# Define angularity bins
ang_bins = np.linspace(0, 0.7, 13)
ang_centers = (ang_bins[1:] + ang_bins[:-1]) / 2

# Colors for different angularities
colors = ['red', 'blue', 'green']
labels = [r'$\lambda_1^{(1)}$', r'$\lambda_1^{(2)}$', r'$\lambda_1^{(3)}$']

# Loop through pT bins
for i in range(len(pt_bin_centers)):
  ax = axes[i]
  
  # Select jets in this pT bin
  pt_mask = (df_jets['pt'] >= pt_bin_edges[i]) & (df_jets['pt'] < pt_bin_edges[i+1])
  jets_in_bin = df_jets[pt_mask]
  
  if len(jets_in_bin) == 0:
    ax.text(0.5, 0.5, 'No jets in bin', ha='center', va='center', transform=ax.transAxes)
    ax.set_title(f'{pt_bin_edges[i]:.0f} < $p_T$ < {pt_bin_edges[i+1]:.0f} GeV\n(0 jets)')
    continue
  
  # Calculate total weighted jets in this bin for normalization
  total_weighted_jets = np.sum(jets_in_bin['ev_weight'])
  
  # Plot each angularity
  for j, ang_col in enumerate(['angk1a1', 'angk1a2', 'angk1a3']):
    # Create weighted histogram
    counts, _ = np.histogram(jets_in_bin[ang_col], bins=ang_bins, weights=jets_in_bin['ev_weight'])
    
    # Calculate unweighted counts for error calculation
    counts_unweighted, _ = np.histogram(jets_in_bin[ang_col], bins=ang_bins)
    
    # Normalize per jet (divide by total weighted jets in bin)
    normalized_counts = counts / total_weighted_jets
    
    # Calculate statistical errors - safer division to avoid RuntimeWarning
    # For weighted histograms: sqrt(N_unweighted) * (weighted_average_weight)
    avg_weights = np.zeros_like(counts_unweighted, dtype=float)
    nonzero_mask = counts_unweighted > 0
    avg_weights[nonzero_mask] = counts[nonzero_mask] / counts_unweighted[nonzero_mask]
    
    counts_errors = np.sqrt(counts_unweighted) * avg_weights
    normalized_errors = counts_errors / total_weighted_jets
    
    # Plot with error bars
    ax.errorbar(ang_centers, normalized_counts, yerr=normalized_errors,
                label=labels[j], color=colors[j], linewidth=2, alpha=0.8,
                fmt='o-', markersize=4, capsize=2)
  
  # Set labels and title
  ax.set_xlabel('Angularity')
  ax.set_ylabel('Normalized count per jet')
  ax.set_title(f'{pt_bin_edges[i]:.0f} < $p_T$ < {pt_bin_edges[i+1]:.0f} GeV\n({len(jets_in_bin)} jets)')
  ax.legend()
  ax.grid(True, alpha=0.3)
  ax.set_yscale('log')
  ax.set_ylim(1e-3, 1)  # Set y-axis range from 1e-3 to 1

plt.tight_layout()
plt.show()

# Print summary information
print("\n=== pT Bin Summary ===")
for i in range(len(pt_bin_centers)):
  pt_mask = (df_jets['pt'] >= pt_bin_edges[i]) & (df_jets['pt'] < pt_bin_edges[i+1])
  jets_in_bin = df_jets[pt_mask]
  total_weighted = np.sum(jets_in_bin['ev_weight']) if len(jets_in_bin) > 0 else 0
  
  print(f"Bin {i+1}: {pt_bin_edges[i]:.0f}-{pt_bin_edges[i+1]:.0f} GeV")
  print(f"  Unweighted jets: {len(jets_in_bin)}")
  print(f"  Weighted jets: {total_weighted:.2e}")
  if len(jets_in_bin) > 0:
    print(f"  Mean angularities:")
    for j, ang_col in enumerate(['angk1a1', 'angk1a2', 'angk1a3']):
      weighted_mean = np.average(jets_in_bin[ang_col], weights=jets_in_bin['ev_weight'])
      print(f"    {labels[j]}: {weighted_mean:.4f}")
  print()
# Out:
# pT bin edges: [  20.           32.61378818   53.18295897   86.72488793  141.42135624
#   230.61430782  376.06030931  613.23756352 1000.        ]
# pT bin centers: [ 25.53968997  41.64730194  67.91381418 110.7463375  180.59287965
#  294.49089617 480.22318542 783.0948624 ]
# === pT Bin Summary ===
# Bin 1: 20-33 GeV
#   Unweighted jets: 51955
#   Weighted jets: 6.36e+02
#   Mean angularities:
#     $\lambda_1^{(1)}$: 0.3567
#     $\lambda_1^{(2)}$: 0.1815
#     $\lambda_1^{(3)}$: 0.1124
#
# Bin 2: 33-53 GeV
#   Unweighted jets: 44747
#   Weighted jets: 1.06e+02
#   Mean angularities:
#     $\lambda_1^{(1)}$: 0.3028
#     $\lambda_1^{(2)}$: 0.1432
#     $\lambda_1^{(3)}$: 0.0864
#
# Bin 3: 53-87 GeV
#   Unweighted jets: 36594
#   Weighted jets: 1.52e+01
#   Mean angularities:
#     $\lambda_1^{(1)}$: 0.2567
#     $\lambda_1^{(2)}$: 0.1131
#     $\lambda_1^{(3)}$: 0.0665
#
# Bin 4: 87-141 GeV
#   Unweighted jets: 28009
#   Weighted jets: 2.00e+00
#   Mean angularities:
# ...

# %% [markdown]
# ### Fixed RuntimeWarning Issue
#
# The previous RuntimeWarning about division by zero has been resolved by using a safer approach for calculating average weights:
#
# **Before (problematic):**
# ```python
# avg_weights = np.where(counts_unweighted > 0, counts / counts_unweighted, 0)
# ```
#
# **After (fixed):**
# ```python
# avg_weights = np.zeros_like(counts_unweighted, dtype=float)
# nonzero_mask = counts_unweighted > 0
# avg_weights[nonzero_mask] = counts[nonzero_mask] / counts_unweighted[nonzero_mask]
# ```
#
# This approach avoids evaluating the division operation when `counts_unweighted` is zero, eliminating the RuntimeWarning while producing identical results.

# %%
# Test the fixed division approach
import numpy as np

# Create test data that would trigger the warning with the old method
counts = np.array([5.0, 3.0, 0.0, 2.0])
counts_unweighted = np.array([2, 1, 0, 1])  # Note: one zero value

print("Test data:")
print(f"counts: {counts}")
print(f"counts_unweighted: {counts_unweighted}")

# Old problematic method (commented out to avoid warning)
# avg_weights_old = np.where(counts_unweighted > 0, counts / counts_unweighted, 0)

# New safe method
avg_weights_new = np.zeros_like(counts_unweighted, dtype=float)
nonzero_mask = counts_unweighted > 0
avg_weights_new[nonzero_mask] = counts[nonzero_mask] / counts_unweighted[nonzero_mask]

print(f"\nUsing safe method:")
print(f"avg_weights: {avg_weights_new}")
print("✅ No RuntimeWarning generated!")
# Out:
# Test data:
# counts: [5. 3. 0. 2.]
# counts_unweighted: [2 1 0 1]
#
# Using safe method:
# avg_weights: [2.5 3.  0.  2. ]
# ✅ No RuntimeWarning generated!

# %% [markdown]
# # RAA - with delta_pT shift

# %%
# Calculate RAA as f(pT) / f(pT + d) for different shift values
shift_values = [1, 2, 5, 7, 10, 15, 20]  # GeV

# Create figure for RAA plots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [3, 1]})

# Colors for different shifts
colors = plt.cm.viridis(np.linspace(0, 1, len(shift_values)))

# Store RAA results for each shift
raa_results = {}

print("=== RAA Calculation: f(pT + d) / f(pT) ===")

# For each shift value, calculate RAA
for i, d in enumerate(shift_values):
  print(f"\nProcessing shift d = {d} GeV...")
  
  # Calculate shifted pT bins
  pt_bins_shifted = pt_bins + d  # Shift bins to higher pT
  
  # Create histogram with shifted pT bins
  # This gives us f(pT + d) by using shifted bins
  counts_shifted, _ = np.histogram(df_jets['pt'], bins=pt_bins_shifted, weights=df_jets['ev_weight'])
  counts_unweighted_shifted, _ = np.histogram(df_jets['pt'], bins=pt_bins_shifted)
  
  # Calculate bin properties for shifted bins
  bin_centers_shifted = (pt_bins_shifted[1:] + pt_bins_shifted[:-1]) / 2
  bin_widths_shifted = pt_bins_shifted[1:] - pt_bins_shifted[:-1]
  
  # Calculate cross-section for shifted bins using same normalization
  cross_section_shifted = (counts_shifted / bin_widths_shifted) * (sigma_gen / sum_weights) / delta_eta
  
  # Calculate errors for shifted cross-section using safer division
  avg_weights_shifted = np.zeros_like(counts_unweighted_shifted, dtype=float)
  nonzero_mask_shifted = counts_unweighted_shifted > 0
  avg_weights_shifted[nonzero_mask_shifted] = counts_shifted[nonzero_mask_shifted] / counts_unweighted_shifted[nonzero_mask_shifted]
  
  counts_errors_shifted = np.sqrt(counts_unweighted_shifted) * avg_weights_shifted
  cross_section_errors_shifted = (counts_errors_shifted / bin_widths_shifted) * (sigma_gen / sum_weights) / delta_eta
  
  # Find corresponding original bins for RAA calculation
  # We match bin_centers_shifted with original bin_centers
  raa_values = []
  raa_errors = []
  pt_centers_for_raa = []
  
  for j, pt_center_shifted in enumerate(bin_centers_shifted):
    # Find the closest original bin center to pt_center_shifted - d (this gives us the original pT)
    pt_center_original = pt_center_shifted - d
    
    # Find closest bin in original data
    closest_idx = np.argmin(np.abs(bin_centers - pt_center_original))
    
    # Only calculate RAA if we have non-zero cross-sections and valid pT range
    if cross_section[closest_idx] > 0 and cross_section_shifted[j] > 0 and pt_center_original > 0:
      raa = cross_section_shifted[j] / cross_section[closest_idx]  # Fixed: f(pT + d) / f(pT)
      
      # Calculate error propagation (assumes uncorrelated errors)
      rel_error_shifted = cross_section_errors_shifted[j] / cross_section_shifted[j] if cross_section_shifted[j] > 0 else 0
      rel_error_original = cross_section_errors[closest_idx] / cross_section[closest_idx] if cross_section[closest_idx] > 0 else 0
      raa_error = raa * np.sqrt(rel_error_shifted**2 + rel_error_original**2)
      
      raa_values.append(raa)
      raa_errors.append(raa_error)
      pt_centers_for_raa.append(pt_center_original)
  
  # Convert to arrays
  raa_values = np.array(raa_values)
  raa_errors = np.array(raa_errors)
  pt_centers_for_raa = np.array(pt_centers_for_raa)
  
  # Store results
  raa_results[d] = {
    'pt_centers': pt_centers_for_raa,
    'raa_values': raa_values,
    'raa_errors': raa_errors,
    'n_points': len(raa_values)
  }
  
  print(f"  Calculated {len(raa_values)} RAA points")
  if len(raa_values) > 0:
    print(f"  pT range: {pt_centers_for_raa.min():.1f} - {pt_centers_for_raa.max():.1f} GeV")
    print(f"  RAA range: {raa_values.min():.3f} - {raa_values.max():.3f}")
  
  # Plot RAA vs pT (main panel - log scale)
  if len(raa_values) > 0:
    ax1.errorbar(pt_centers_for_raa, raa_values, yerr=raa_errors,
                fmt='o-', color=colors[i], label=f'd = {d} GeV',
                markersize=4, capsize=2, alpha=0.8, linewidth=2)

# Set plot properties for main panel
ax1.set_ylabel(r'$R_{AA} = \frac{d^2\sigma/dp_T d\eta (p_T + d)}{d^2\sigma/dp_T d\eta (p_T)}$', fontsize=14)
ax1.set_title('Nuclear Modification Factor RAA vs Jet pT', fontsize=16, fontweight='bold')
ax1.set_xscale('log')
ax1.set_xlim(25, 800)
ax1.set_ylim(0, 2.5)
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10, ncol=2)

# Add horizontal line at RAA = 1
ax1.axhline(y=1, color='black', linestyle='--', alpha=0.7, linewidth=1.5, label='RAA = 1')

# Bottom panel - linear y-scale for better visibility
for i, d in enumerate(shift_values):
  if d in raa_results and len(raa_results[d]['raa_values']) > 0:
    ax2.errorbar(raa_results[d]['pt_centers'], raa_results[d]['raa_values'], 
                yerr=raa_results[d]['raa_errors'],
                fmt='o-', color=colors[i], markersize=4, capsize=2, alpha=0.8, linewidth=2)

ax2.set_xlabel(r'Jet $p_T$ [GeV]', fontsize=14)
ax2.set_ylabel(r'$R_{AA}$', fontsize=14)
ax2.set_xscale('log')
ax2.set_xlim(25, 800)
ax2.set_ylim(0, 2)
ax2.grid(True, alpha=0.3)
ax2.axhline(y=1, color='black', linestyle='--', alpha=0.7, linewidth=1.5)

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"\n=== RAA Summary Statistics ===")
for d in shift_values:
  if d in raa_results and len(raa_results[d]['raa_values']) > 0:
    raa_vals = raa_results[d]['raa_values']
    pt_vals = raa_results[d]['pt_centers']
    
    # Calculate average RAA in different pT ranges
    low_pt_mask = (pt_vals >= 30) & (pt_vals < 100)
    high_pt_mask = pt_vals >= 100
    
    print(f"\nShift d = {d} GeV:")
    print(f"  Total points: {len(raa_vals)}")
    print(f"  Overall RAA: {raa_vals.mean():.3f} ± {raa_vals.std():.3f}")
    
    if np.any(low_pt_mask):
      low_pt_raa = raa_vals[low_pt_mask]
      print(f"  RAA (30-100 GeV): {low_pt_raa.mean():.3f} ± {low_pt_raa.std():.3f} ({np.sum(low_pt_mask)} points)")
    
    if np.any(high_pt_mask):
      high_pt_raa = raa_vals[high_pt_mask]
      print(f"  RAA (>100 GeV): {high_pt_raa.mean():.3f} ± {high_pt_raa.std():.3f} ({np.sum(high_pt_mask)} points)")

# Save RAA results to CSV
raa_df_list = []
for d in shift_values:
  if d in raa_results and len(raa_results[d]['raa_values']) > 0:
    for j in range(len(raa_results[d]['raa_values'])):
      raa_df_list.append({
        'shift_d': d,
        'pt_center': raa_results[d]['pt_centers'][j],
        'raa_value': raa_results[d]['raa_values'][j],
        'raa_error': raa_results[d]['raa_errors'][j]
      })

if raa_df_list:
  raa_df = pd.DataFrame(raa_df_list)
  raa_df.to_csv('raa_analysis.csv', index=False)
  print(f"\nRAA results saved to 'raa_analysis.csv' ({len(raa_df_list)} data points)")
# Out:
# === RAA Calculation: f(pT + d) / f(pT) ===
#
# Processing shift d = 1 GeV...
#   Calculated 30 RAA points
#   pT range: 21.4 - 938.9 GeV
#   RAA range: 0.805 - 0.993
#
# Processing shift d = 2 GeV...
#   Calculated 30 RAA points
#   pT range: 21.4 - 938.9 GeV
#   RAA range: 0.675 - 0.996
#
# Processing shift d = 5 GeV...
#   Calculated 30 RAA points
#   pT range: 21.4 - 938.9 GeV
#   RAA range: 0.395 - 0.953
#
# Processing shift d = 7 GeV...
#   Calculated 30 RAA points
#   pT range: 21.4 - 938.9 GeV
#   RAA range: 0.270 - 0.921
#
# Processing shift d = 10 GeV...
#   Calculated 30 RAA points
#   pT range: 21.4 - 938.9 GeV
#   RAA range: 0.172 - 0.910
#
# Processing shift d = 15 GeV...
#   Calculated 30 RAA points
#   pT range: 21.4 - 938.9 GeV
#   RAA range: 0.085 - 0.835
#
# Processing shift d = 20 GeV...
#   Calculated 30 RAA points
#   pT range: 21.4 - 938.9 GeV
#   RAA range: 0.048 - 0.794
# === RAA Summary Statistics ===
#
# Shift d = 1 GeV:
#   Total points: 30
# ...
